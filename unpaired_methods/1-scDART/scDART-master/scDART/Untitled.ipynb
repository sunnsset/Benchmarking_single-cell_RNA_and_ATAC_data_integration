# %%
conda list
# Out:
# # packages in environment at /data1/xcx/anaconda3/envs/scDART:
# #
# # Name                    Version                   Build  Channel
# _ipython_minor_entry_point 8.7.0                hb6b4a82_0    conda-forge
# _libgcc_mutex             0.1                        main
# _openmp_mutex             5.1                       1_gnu
# anyio                     3.6.2              pyhd8ed1ab_0    conda-forge
# argon2-cffi               21.3.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0          py310h5764c6d_2    conda-forge
# asttokens                 2.2.1              pyhd8ed1ab_0    conda-forge
# attrs                     22.1.0             pyh71513ae_1    conda-forge
# babel                     2.11.0             pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# backports                 1.0                pyhd8ed1ab_3    conda-forge
# ...

# %%
pip install umap==0.4
# Out:
# ERROR: Could not find a version that satisfies the requirement umap==0.4 (from versions: 0.1.macosx-10.5-x86_64, 0.1.1.macosx-10.5-x86_64, 0.1, 0.1.1)
# ERROR: No matching distribution found for umap==0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install umap-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 971.0 kB/s eta 0:00:00 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 13.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 4.7 MB/s eta 0:00:0000:010:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 19.1 MB/s eta 0:00:0000:0100:01
# ...
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82814 sha256=db41983bbe4e1d8a66ecce166426084afee036012e559ec704067ea9f09732ad
#   Stored in directory: /home/xcx/.cache/pip/wheels/73/d4/20/721044c5f3d1ab1c08a9d6d200964f2543974496570117e59b
# ...
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55496 sha256=2f00887aa5f9131fb11cca15d8bb69625ea0115103febf83792905df452ad268
# ...
